# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import csv
import pandas as pd
import os

# %%
df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_39361.sed',header=None,skiprows=6)
df = df[0].str.split(expand=True)
plt.figure()
plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[1].to_numpy(dtype=float),label='BC03 normalized 0.5 gyr')

df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_39361_no_dust.137',header=None,skiprows=6)
df = df[0].str.split(expand=True)
plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[1].to_numpy(dtype=float),label='BC03 no dust 0.5 gyr')
#plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[2].to_numpy(dtype=float),label='BC03 no dust 0.9 Gyr',color='green')


df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_39361_elines.137',header=None,skiprows=6)
df = df[0].str.split(expand=True)
#print(df)
plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[1].to_numpy(dtype=float),label='BC03 only galaxy emission lines 0.5 gyr')
#plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[2].to_numpy(dtype=float),label='BC03 emission lines 0.9 Gyr',color='red')

df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_39361_elines_and_AGN.137',header=None,skiprows=6)
df = df[0].str.split(expand=True)
#print(df)
plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[1].to_numpy(dtype=float),label='BC03 galaxy lines and AGN contin. 0.5 gyr')
#plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[2].to_numpy(dtype=float),label='BC03 emission lines and BH 0.9 Gyr',color='purple')

df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_39361_AGN_elines_300.137',header=None,skiprows=6)
df = df[0].str.split(expand=True)
#print(df)
plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[1].to_numpy(dtype=float),label='BC03 only AGN lines (300km/s) 0.5 gyr')
#plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[2].to_numpy(dtype=float),label='BC03 emission lines and BH+ BH elines 0.9 Gyr',color='orange')

df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_39361_AGN_elines_1000.137',header=None,skiprows=6)
df = df[0].str.split(expand=True)
#print(df)
plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[1].to_numpy(dtype=float),label='BC03 only AGN lines (1000 km/s) 0.5 gyr')
#plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[2].to_numpy(dtype=float),label='BC03 galaxy and AGN continuum 0.9 Gyr',color='darkgray')


df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_39361_mod_no_elines.137',header=None,skiprows=6)
df = df[0].str.split(expand=True)
#print(df)
plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[1].to_numpy(dtype=float),label='BC03 gal and AGN continuum 0.5 gyr')
#plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[2].to_numpy(dtype=float),label='BC03 galaxy and AGN continuum + AGN lines (300km/s) 0.9 Gyr',color='gold')


df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_39361_everything.137',header=None,skiprows=6)
df = df[0].str.split(expand=True)
#print(df)
plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[1].to_numpy(dtype=float),label='BC03 everything 0.5 gyr')
#plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[2].to_numpy(dtype=float),label='BC03 galaxy and AGN continuum + AGN lines (1000km/s) 0.9 Gyr',color='turquoise')

#df = pd.read_csv('no_dust.sed',header=None,skiprows=6)
#df = df[0].str.split(expand=True)
#plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[1].to_numpy(dtype=float),label='BC03 no dust 0.5 gyr')
#plt.plot(df[0].to_numpy(dtype=float),3.826e+33*df[2].to_numpy(dtype=float),label='BC03 no dust 0.9 Gyr')
#plt.plot(array_wavelength,(modifiedarray_flux)+flux,color='gold',alpha=1,lw=2,zorder=70)  ## our galaxy SED
#plt.plot(array_wavelength,(modifiedarray_flux)+flux/10,color='tomato',alpha=0.4,lw=2,zorder=70)  ## our galaxy SED
#plt.plot(array_wavelength,(modifiedarray_flux)+flux/1000,color='darkviolet',alpha=0.4,lw=2,zorder=70)  ## our galaxy SED
#plt.plot(array_wavelength,(AGN_modifiedarray_flux_2+AGN_2)/1000,color='navy',lw=2) ## our AGN SED
#plt.plot(array_wavelength,(modifiedarray_flux+flux+AGN_modifiedarray_flux_2+AGN_2)/1e42,color='black',lw=2) ## our AGN SED
plt.semilogy()
plt.ylim(1e35,1e43)
#plt.xlim(5*1e2,2*1e5)
plt.xlim(0,10000)
plt.legend(frameon=False)
#plt.ylim()

# %% [markdown]
# This code is used to plot SED files that are produced from the BC03 code and extracted with the galaxevpl function.
# There can be multiple time steps in the files.
#
# All of this code is really straightforward, extracting the values from the columns and then plotting them, sometimes on subplots for different metallicities.
#
# Some cells have multiple flux computations because we were trying to match units.
# But for f_lambda the output is simply in solar luminosity/A and this seems to be pretty correct when comparing to other data/ findings.

# %%
df = pd.read_csv('ASCII/bc2003_lr_BaSeL_m22_chab_ssp.130','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)

wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
plt.plot(wavelength,flux, label='0.5')
flux = df[2].astype('float64').to_numpy()
plt.plot(wavelength,flux,label='1')
flux = df[3].astype('float64').to_numpy()
plt.plot(wavelength,flux,label='2')
flux = df[4].astype('float64').to_numpy()
plt.plot(wavelength,flux,label='5')
flux = df[5].astype('float64').to_numpy()
plt.plot(wavelength,flux,label='10')
plt.xscale('log')
plt.yscale('log')
plt.legend()
plt.show()

# %%
#galaxy at age 0.153 (corresponds to z = 8)
df = pd.read_csv('ASCII/bc2003_lr_BaSeL_m22_chab_ssp.120','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
print(wavelength,flux)

flux = 3.826e+33*flux
flux = (flux)/((4*np.pi*(10**((mu/5)+1))**2))
flux = flux*(0.00000000000000000032408**2)
print(flux)
flux = flux*(3*10e+18)/(wavelength**2)
print(flux)
wavelength = 0.0001*wavelength
plt.plot(wavelength,flux*10e+20)
plt.xscale('log')
plt.yscale('log')
plt.xlim(1.1,5)
#plt.ylim(10e-3,10e+1)
plt.xlabel(r'$\mu$ m')
plt.ylabel(r'$f_{\lambda}$ ( erg/s/A/cm^2)')
plt.show()

# %%
#galaxy at age 0.153 (corresponds to z = 8)
df = pd.read_csv('ASCII/bc2003_lr_BaSeL_m22_chab_ssp.120','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
print(wavelength,flux)

flux = 3.826e+33*flux
flux = (flux)/((4*np.pi*(10**((mu/5)+1))**2))
flux = flux*(0.00000000000000000032408**2)

flux = flux*(3*10e-5)/(wavelength**2)

wavelength = 0.0001*wavelength
plt.plot(wavelength,flux*10e+20)
plt.xscale('log')
plt.yscale('log')
plt.xlim(1.1,5)
#plt.ylim(10e-3,10e+1)
plt.xlabel(r'$\mu$ m')
plt.ylabel(r'$f_{\lambda}$ ( erg/s/A/cm^2)')
plt.show()

# %%
#galaxy at age 0.153 (corresponds to z = 8)
df = pd.read_csv('ASCII/bc2003_lr_BaSeL_m22_chab_ssp.120','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
print(wavelength,flux)

flux = 3.826e+33*flux
flux = (flux)/((4*np.pi*(10**2)))
flux = flux*(0.00000000000000000032408**2)

flux = flux*(3*10e-5)/(wavelength**2)

wavelength = 0.0001*wavelength
plt.plot(wavelength,flux)
plt.xscale('log')
plt.yscale('log')
plt.xlim(1.1,5)
#plt.ylim(10e-3,10e+1)
plt.xlabel(r'$\mu$ m')
plt.ylabel(r'$f_{\lambda}$ ( erg/s/A/cm^2)')
plt.show()

# %%
#galaxy at age 0.153 (corresponds to z = 8)
df = pd.read_csv('ASCII/m22','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
print(df)
names = ['0.001','0.01','0.1','0.4','1','4','13']
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
wavelength = 0.0001*wavelength
i = 1
while i < 8:

    flux = df[i].astype('float64').to_numpy()

    flux = 3.826e+33*flux
    flux = (flux)/((4*np.pi*(10**((mu/5)+1))**2))
    flux = flux*(0.00000000000000000032408**2)
    #print(flux)
    flux = flux*(3*10e+18)
    #print(flux)
    plt.plot(wavelength,flux*10e+20,label=names[i-1])
    i+=1
plt.xscale('log')
plt.yscale('log')
plt.ylim(10e-6,40)
#plt.ylim(10e-3,10e+1)
plt.legend()
plt.xlabel(r'Wavelength in $\mu$ m')
plt.ylabel(r'$f_{\lambda}$ ($10^{-20}$ erg/s/A/cm^2)')
plt.savefig('Figures/sed_different_age')
plt.show()
0.001,0.01,0.1,0.4,1,4,13

# %%
#galaxy at age 0.153 (corresponds to z = 8)
df = pd.read_csv('ASCII/m22-2','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
print(df)
names = ['0.001','0.01','0.1','0.4','1','4','13']
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
#wavelength = 0.0001*wavelength
i = 1
while i < 8:

    flux = df[i].astype('float64').to_numpy()
    #flux = flux*3.2e-7
    #flux = 3.826e+33*flux

    #flux = (flux)/((4*np.pi*(10**((mu/5)+1))**2))
    #flux = flux*(0.00000000000000000032408**2)
    #print(flux)
    #flux = flux*(3*10e+18)/(wavelength**2)
    #flux = (flux)/((4*np.pi*(10**2)))
    #flux = flux*(0.00000000000000000032408**2)
    #print(flux)
    #flux = flux*(3*10e+18)
    #print(flux)
    plt.plot(wavelength,flux,label=names[i-1])
    i+=1
plt.xscale('log')
plt.yscale('log')
#plt.ylim(10e-8,1)
#plt.ylim(10e-3,10e+1)
plt.legend()
plt.xlabel(r'Wavelength in A')
plt.ylabel(r'$f_{\lambda}$ ( L_sun/A)')
plt.savefig('Figures/sed_different_age')
plt.show()
0.001,0.01,0.1,0.4,1,4,13

# %%
cols = 4 
rows = 2
i = 0
j = 0
fig, axes = plt.subplots(rows, cols, figsize=(16, 12))
files = ['ASCII/m22','ASCII/m32','ASCII/m42','ASCII/m52','ASCII/m62','ASCII/m72','ASCII/m82']
names = ['0.001','0.01','0.1','0.4','1','4','13']
x = 0
while x < len(files):
    #galaxy at age 0.153 (corresponds to z = 8)
    print(files[x])
    df = pd.read_csv(files[x],'/s', header=None, skiprows=6)
    df = df[0].str.split(expand=True)
    print(df)
    #distance modulus at z = 8
    mu = 49.53
    wavelength = df[0].astype('float64').to_numpy()
    wavelength = 0.0001*wavelength
    f = 1
    while f < 8:
        flux = df[f].astype('float64').to_numpy()
        flux = 3.826e+33*flux
        flux = (flux)/((4*np.pi*(10**((mu/5)+1))**2))
        flux = flux*(0.00000000000000000032408**2)
        #print(flux)
        flux = flux*(3*10e+18)
        #print(flux)
        axes[i][j].plot(wavelength,flux*10e+20,label=names[f-1])
        f+=1
    axes[i][j].set_xscale('log')
    axes[i][j].set_yscale('log')
    axes[i][j].set_title(files[x])
    axes[i][j].set_ylim(10e-6,40)
    axes[i][j].set_xlim(0.01,100)
    axes[i][j].legend()
    axes[i][j].set_xlabel(r'Wavelength in $\mu$ m')
    axes[i][j].set_ylabel(r'$f_{\lambda}$ ($10^{-20}$ erg/s/A/cm^2)')
    x += 1
    j += 1
    if x == 4:
        i +=1
        j = j-4
plt.tight_layout()
plt.savefig('Figures/sed_different_metallicity')
plt.show()
0.001,0.01,0.1,0.4,1,4,13

# %%
#exponential with tau = 0.3
#galaxy at age 0.153 (corresponds to z = 8)
df = pd.read_csv('ASCII/model1-SED.20','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
print(df)
names = ['0.001','0.01','0.1','0.4','1','4','13']
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
wavelength = 0.0001*wavelength
i = 1
while i < 8:

    flux = df[i].astype('float64').to_numpy()

    flux = 3.826e+33*flux
    flux = (flux)/((4*np.pi*(10**((mu/5)+1))**2))
    flux = flux*(0.00000000000000000032408**2)
    #print(flux)
    flux = flux*(3*10e+18)
    #print(flux)
    plt.plot(wavelength,flux*10e+20,label=names[i-1])
    i+=1
plt.xscale('log')
plt.yscale('log')
plt.ylim(10e-6,40)
#plt.ylim(10e-3,10e+1)
plt.legend()
plt.xlabel(r'Wavelength in $\mu$ m')
plt.ylabel(r'$f_{\lambda}$ ($10^{-20}$ erg/s/A/cm^2)')
plt.savefig('Figures/sed_model1')
plt.show()

# %%
#single burst at 40 Gyr

#galaxy at age 0.153 (corresponds to z = 8)
df = pd.read_csv('ASCII/model2-SED.20','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
print(df)
names = ['0.001','0.01','0.1','0.4','1','4','13']
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
wavelength = 0.0001*wavelength
i = 1
while i < 8:

    flux = df[i].astype('float64').to_numpy()

    flux = 3.826e+33*flux
    flux = (flux)/((4*np.pi*(10**((mu/5)+1))**2))
    flux = flux*(0.00000000000000000032408**2)
    #print(flux)
    flux = flux*(3*10e+18)
    #print(flux)
    plt.plot(wavelength,flux*10e+20,label=names[i-1])
    i+=1
plt.xscale('log')
plt.yscale('log')
plt.ylim(10e-6,40)
#plt.ylim(10e-3,10e+1)
plt.legend()
plt.xlabel(r'Wavelength in $\mu$ m')
plt.ylabel(r'$f_{\lambda}$ ($10^{-20}$ erg/s/A/cm^2)')
plt.savefig('Figures/sed_model2')
plt.show()

# %%
#linearly decreasing, sfr=0 at tau = 300 gyr
#tcut=500

#galaxy at age 0.153 (corresponds to z = 8)
df = pd.read_csv('ASCII/model3-SED.20','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
print(df)
names = ['0.001','0.01','0.1','0.4','1','4','13']
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
wavelength = 0.0001*wavelength
i = 1
while i < 8:

    flux = df[i].astype('float64').to_numpy()

    flux = 3.826e+33*flux
    flux = (flux)/((4*np.pi*(10**((mu/5)+1))**2))
    flux = flux*(0.00000000000000000032408**2)
    #print(flux)
    flux = flux*(3*10e+18)
    #print(flux)
    plt.plot(wavelength,flux*10e+20,label=names[i-1])
    i+=1
plt.xscale('log')
plt.yscale('log')
plt.ylim(10e-6,40)
#plt.ylim(10e-3,10e+1)
plt.legend()
plt.xlabel(r'Wavelength in $\mu$ m')
plt.ylabel(r'$f_{\lambda}$ ($10^{-20}$ erg/s/A/cm^2)')
plt.savefig('Figures/sed_model3')
plt.show()

# %%
#linearly decreasing, sfr=0 at tau = 300 gyr
#tcut=500

#galaxy at age 0.153 (corresponds to z = 8)
df = pd.read_csv('ASCII/user-defined2.6','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
print(df)
names = ['0.001','1']
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
wavelength = 0.0001*wavelength
i = 0
while i < len(names):

    flux = df[i].astype('float64').to_numpy()

    #flux = 3.826e+33*flux
    #flux = (flux)/((4*np.pi*(10**((mu/5)+1))**2))
    #flux = flux*(0.00000000000000000032408**2)
    #print(flux)
    #flux = flux*(3*10e+18)
    #print(flux)
    plt.scatter(wavelength,flux,label='Z=0 at '+str(names[i-1]))
    i+=1

"""
df = pd.read_csv('ASCII/user-defined-z5.6','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
print(df)
names = ['0.001','1']
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
wavelength = 0.0001*wavelength
i = 0
while i < len(names):

    flux = df[i].astype('float64').to_numpy()

    #flux = 3.826e+33*flux
    #flux = (flux)/((4*np.pi*(10**((mu/5)+1))**2))
    #flux = flux*(0.00000000000000000032408**2)
    #print(flux)
    #flux = flux*(3*10e+18)
    #print(flux)
    plt.scatter(wavelength,flux,label='Z=5 at '+str(names[i-1]))
    i+=1
"""
plt.xscale('log')
plt.yscale('log')
#plt.ylim(10e-6,40)
#plt.ylim(10e-3,10e+1)
plt.legend()
plt.xlabel(r'Wavelength in $\mu$ m')
plt.ylabel(r'$f_{\lambda}$ ($L_{\odot}$ /A/$L_{/odot}$)')
plt.savefig('Figures/understand')
plt.show()

# %%
cols = 4
rows = 2
i = 0
j = 0
fig, axes = plt.subplots(rows, cols, figsize=(16, 12))
files = ['ASCII/dust0-0001.1','ASCII/dust0-05.1','ASCII/dust0-1.1','ASCII/dust0-15.1','ASCII/dust0-2.1','ASCII/dust0-5.1','ASCII/dust0-9.1']
names = ['0','0.01','1','5']
tau = [r'$\tau = $0.0001',r'$\tau = $0.05',r'$\tau = $0.1',r'$\tau = $0.15',r'$\tau = $0.2',r'$\tau = $0.5',r'$\tau = $0.9',]
x = 0
while x < len(files):
    #galaxy at age 0.153 (corresponds to z = 8)
    print(files[x])
    df = pd.read_csv(files[x],'/s', header=None, skiprows=6)
    df = df[0].str.split(expand=True)
    print(df)
    #distance modulus at z = 8
    mu = 49.53
    wavelength = df[0].astype('float64').to_numpy()
    wavelength = 0.0001*wavelength
    f = 0
    while f < len(names):
        flux = df[f].astype('float64').to_numpy()

        axes[i][j].plot(wavelength,flux*10e+20,label="age in gyr = "+str(names[f]))
        f+=1
    axes[i][j].set_xscale('log')
    axes[i][j].set_yscale('log')
    axes[i][j].set_title(tau[x])
    axes[i][j].set_ylim(10e14,10e20)
    axes[i][j].set_xlim(0.01,100)
    axes[i][j].legend()
    axes[i][j].set_xlabel(r'Wavelength in $\mu$ m')
    axes[i][j].set_ylabel(r'$f_{\lambda}$)')
    x += 1
    j += 1
    if x == 4:
        i +=1
        j = j-4
plt.tight_layout()
plt.savefig('Figures/attenuation-test')
plt.show()

# %%
cols = 4
rows = 2
i = 0
j = 0
fig, axes = plt.subplots(rows, cols, figsize=(16, 12))
files = ['ASCII/dust0-0001.multi_mag_AB','ASCII/dust0-05.multi_mag_AB','ASCII/dust0-1.multi_mag_AB','ASCII/dust0-15.multi_mag_AB','ASCII/dust0-2.multi_mag_AB','ASCII/dust0-5.multi_mag_AB','ASCII/dust0-9.multi_mag_AB']
tau = [r'$\tau = $0.0001',r'$\tau = $0.05',r'$\tau = $0.1',r'$\tau = $0.15',r'$\tau = $0.2',r'$\tau = $0.5',r'$\tau = $0.9',]
x = 0
while x<len(files):
    names=['z', 'LTT','tz','dm','278','279','280','281','282','283','286','291']
    df = pd.read_csv(files[x],'/s', header=None, skiprows=41)
    df = df[0].str.split(expand=True)
    print(df)

    redshift = df[0].astype('float64').to_numpy()
    f = 4
    while f < len(names):
        print(f)
        axes[i][j].plot(redshift,df[f].astype('float64').to_numpy(),label='filter'+str(names[f]))
        f+=1
    
    axes[i][j].set_title(tau[x])
    
    axes[i][j].legend()
    axes[i][j].set_xlabel(r'Redshift')
    axes[i][j].set_ylabel(r'AB Magnitude')
    x += 1
    j += 1
    if x == 4:
        i +=1
        j = j-4
    
    #plt.yscale('log')
    #plt.ylim(10e-6,40)
    #plt.ylim(10e-3,10e+1)

fig.tight_layout()
plt.savefig('Figures/magnitude-z-tau')
plt.show()

# %%
df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_0_age=995000000.000.sed','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)

flux = 3.826e+33*flux
#flux = 3.34e-19*flux*wavelength*wavelength
#flux = flux*(3e+18/wavelength)
#flux = (flux)/((4*np.pi*(10**2)))
#flux = flux*(0.00000000000000000032408**2)

#flux = flux*(3*10e-5)/(wavelength**2)
with open('wavelength.txt', mode="w") as f:
    [f.write(str(i)+'\n') for i in wavelength]
wavelength = 0.0001*wavelength
plt.plot(wavelength,flux)


df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_1_age=995000000.000.sed','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)

flux = 3.826e+33*flux
#flux = 3.34e-19*flux*wavelength*wavelength
#flux = flux*(3e+18/wavelength)
wavelength = 0.0001*wavelength
plt.plot(wavelength,flux)


df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_2_age=904000000.000.sed','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)

flux = 3.826e+33*flux
#flux = 3.34e-19*flux*wavelength*wavelength
#flux = flux*(3e+18/wavelength)
wavelength = 0.0001*wavelength
plt.plot(wavelength,flux)


df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_12397_age=995000000.000.sed','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)

flux = 3.826e+33*flux
#flux = 3.34e-19*flux*wavelength*wavelength
#flux = flux*(3e+18/wavelength)
wavelength = 0.0001*wavelength
plt.plot(wavelength,flux)



df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_8704_age=995000000.000.sed','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)

flux = 3.826e+33*flux
#flux = 3.34e-19*flux*wavelength*wavelength
#flux = flux*(3e+18/wavelength)
wavelength = 0.0001*wavelength
plt.plot(wavelength,flux)


plt.xscale('log')
plt.yscale('log')
#plt.xlim(1.1,5)
#plt.ylim(10e-3,10e+1)
plt.xlabel(r'$\mu$ m')
plt.ylabel(r'$f_{\lambda} $ ( erg/s/A)')
#plt.show()

# %%
def bisection(array,value):
    '''Given an ``array`` , and given a ``value`` , returns an index j such that ``value`` is between array[j]
    and array[j+1]. ``array`` must be monotonic increasing. j=-1 or j=len(array) is returned
    to indicate that ``value`` is out of range below and above respectively.'''
    n = len(array)
    if (value < array[0]):
        return -1
    elif (value > array[n-1]):
        return n
    jl = 0# Initialize lower
    ju = n-1# and upper limits.
    while (ju-jl > 1):# If we are not yet done,
        jm=(ju+jl) >> 1# compute a midpoint with a bitshift
        if (value >= array[jm]):
            jl=jm# and replace either the lower limit
        else:
            ju=jm# or the upper limit, as appropriate.
        # Repeat until the test condition is satisfied.
    if (value == array[0]):# edge cases at bottom
        return 0
    elif (value == array[n-1]):# and top
        return n-1
    else:
        return jl

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)


galaxy_num = [0]
library = pd.read_csv('TNG_50_library/library_galaxies.txt', header=None)

for i in galaxy_num:
    age_gal = library[1][library[0]==i]
    age_gal_i = age_gal.to_numpy()[0]

    age_row = [0]
    ages = pd.read_csv('TNG_50_library\TNG50_out_17_gal_'+str(i)+'.ised_ASCII', header=None, skiprows = lambda x: x not in age_row)
    ages = ages[0].str.split(expand=True, n=2023)
    ages = ages.drop(0,axis=1)
    ages = np.float64(ages.to_numpy()[0])
    

    index_row = bisection(ages, age_gal_i)
    rows_age = [index_row+5, index_row+6, index_row+7]
    print(rows_age)

    headerplustail_rows = [0,1,2,3,4,5,6,281,280,279,278,277,276,275,274,273,272,271,270]
    #df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_'+str(i)+'.ised_ASCII','/s', header=None, skiprows=headerplustail_rows)
    df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_'+str(i)+'.ised_ASCII','/s', header=None, skiprows=lambda x: x not in rows_age)
    df = df[0].str.split(expand=True, n=2024)
    #print(df.loc[[0]])

    first_col = df[0]
    last_col = df[2024]
    df = df.drop(0, axis=1)
    df = df.drop(2024, axis=1)

    df.astype(float)
    df = df.T

    
    specific_rows = [6]
    wavelength = pd.read_csv('TNG_50_library\TNG50_out_17_gal_'+str(i)+'.ised_ASCII', header=None, skiprows = lambda x: x not in specific_rows)
    wavelength = wavelength[0].str.split(expand=True, n=2023)
    wavelength = wavelength.drop(0, axis=1)
    wavelength = wavelength.T
    xvals = wavelength[0].to_numpy()
    #print(xvals)
    xvals = np.float64(xvals)
    print(xvals)

    
    xx = [0,1,2]
    for x in xx:
        plt.loglog(xvals, np.float64(df[x].to_numpy()),label=str(x))

    df = df.astype(float)
    df[3] = np.ones(2023)*100000000
    #print(df)
    df[0] = df.loc[:,[0,3]].sum(axis=1)
    #df[0] = df[0]+df[3]
    df[3] = np.ones(2023)*100000000
    df[1] = df.loc[:,[1,3]].sum(axis=1)
    df[3] = np.ones(2023)*100000000
    df[2] = df.loc[:,[2,3]].sum(axis=1)
    #print(df)
    df = df.drop(3, axis=1)
    #xx = [40,50,60,70,80,90,150,155,160]
    xx = [0,1,2]
    for x in xx:
        plt.loglog(xvals, np.float64(df[x].to_numpy()),label=str(x))

    plt.ylim(1e7,1e9)
    plt.legend()
    

    df = df.T
    
    df.insert(0, 0, first_col, True)
    df.insert(2024, 2024, last_col, True)
    #print(df)
    middle = df.astype(str)
    middle = middle.apply(lambda x: '       '.join(x.dropna()), axis=1)
    #print(middle)


    front = pd.read_csv('TNG_50_library\TNG50_out_17_gal_'+str(i)+'.ised_ASCII','/s', header=None, skipfooter=280-rows_age[0]+2)

    #print(front)
    back = pd.read_csv('TNG_50_library\TNG50_out_17_gal_'+str(i)+'.ised_ASCII','/s', header=None, skiprows=rows_age[-1]+1)
    #print(back)

    frames = [front,middle,back]
    result = pd.concat(frames)
    print(result)
    result.to_csv('TNG_50_library\TNG50_out_17_gal_'+str(i)+'_mod.ised_ASCII',header=None,index=None)
    #add values to each row
    #replot row to check
    #get rows from the og data frame
    # join all modified row
    #rewrite to file
    # reconvert to .ised

    plt.show()

# %%
df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_0_mod.152','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)

#flux = 3.826e+33*flux
#flux = 3.34e-19*flux*wavelength*wavelength
#flux = flux*(3e+18/wavelength)
wavelength = 0.0001*wavelength
plt.loglog(wavelength,flux)

# %%
library = pd.read_csv('TNG_50_library/library_galaxies.txt', header=None)


galaxy_num = [0,1,2,3,4,5]
for i in galaxy_num:
    age_gal = library[1][library[0]==i]
    age_gal_i = int(age_gal.to_numpy()[0])

    df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_'+str(i)+'_age='+str(age_gal_i)+'.000.sed', header=None, skiprows=6)
    df = df[0].str.split(expand=True)
    #distance modulus at z = 8
    mu = 49.53
    wavelength = df[0].astype('float64').to_numpy()
    flux = df[1].astype('float64').to_numpy()
    #print(wavelength,flux)

    flux = 3.826e+33*flux
    #flux = 3.34e-19*flux*wavelength*wavelength
    #flux = flux*(3e+18/wavelength)
    #flux = (flux)/((4*np.pi*(10**2)))
    #flux = flux*(0.00000000000000000032408**2)

    plt.loglog(wavelength,flux,label='Galaxy '+str(i))
galaxy_num = [0,1,3]
for i in galaxy_num:
    age_gal = library[1][library[0]==i]
    age_gal_i = int(age_gal.to_numpy()[0])
    df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_'+str(i)+'_mod_age='+str(age_gal_i)+'.000_mod.sed', header=None, skiprows=6)
    df = df[0].str.split(expand=True)
    #distance modulus at z = 8
    mu = 49.53
    wavelength = df[0].astype('float64').to_numpy()
    flux = df[1].astype('float64').to_numpy()
    #print(wavelength,flux)

    flux = 3.826e+33*flux
    #flux = 3.34e-19*flux*wavelength*wavelength
    #flux = flux*(3e+18/wavelength)
    #flux = (flux)/((4*np.pi*(10**2)))
    #flux = flux*(0.00000000000000000032408**2)

    plt.loglog(wavelength,flux,label='Galaxy '+str(i)+' with BH')
plt.ylim(1e38,1e39)
plt.legend()

# %%
import numpy as np
from scipy.interpolate import splrep, splev, splint
import os
import pandas as pd
import matplotlib.pyplot as plt
import math
import time
import numpy as np
from numpy import *
from collections import Counter
from scipy import interpolate
import matplotlib.gridspec as gridspec
from matplotlib.ticker import MaxNLocator
from matplotlib.backends.backend_pdf import PdfPages
import sys
import os
import pylab
from matplotlib import rc
from matplotlib.colors import LogNorm
import scipy
import scipy.integrate
from scipy.optimize import curve_fit


### Parameters for the AGN SED
nu_IR=0.01*3.2899*1e15 #0.01 Ryd to Hz
alpha_UV=-0.5
alpha_x=-1.0

# taken from Table1 of Thomas+16 paper
Ax2=-0.18
Ax1=0.0
Ax0=0.59
B=0.250
b3x1=0.034
b3x0=-0.019

b1x2=0.391
b1x1=-0.83
b1x0=0.61
ax2=-0.3
ax1=0.4
ax0=-0.82


def S(L_BH, M_BH):
  # M_BH in Msun
  # L_BH/L_Edd the Eddington ratio 
  # Here our L is in real units.
  #L_Edd = M_BH*4.*np.pi*cte_G*cte_m_p*cte_c/cte_sigma_t
  L_Edd = 1.26*1e38 * M_BH # in erg/s
  S     = np.log10((L_BH/L_Edd)/M_BH)
  #     = np.log10((L_BH)/M_BH)
  return S

def R(r_corona, M_BH):
  # r_corona the coronal radius (inner edge of the visible portion of the disk). Should be in units of r_g
  # r_g the gravitational radius, r_g = cte_G*M_BH/cte_c**2
  #r_g   = cte_G*M_BH/cte_c**2
  #R     = np.log10(r_corona/r_g)
  R = np.log10(r_corona)
  return R

def f1(L_BH, M_BH, r_corona):
  f1    = Ax2*R(r_corona, M_BH)*R(r_corona, M_BH) + Ax1*R(r_corona, M_BH) + Ax0 + B*S(L_BH,M_BH)
  return f1

def f2(L_BH, M_BH, r_corona):
  #print(R(r_corona, M_BH))
  #print(S(L_BH,M_BH))
  #print(L_BH,M_BH,r_corona)
  #print('ho')
  f2    = (b3x1*R(r_corona, M_BH)+b3x0)*np.power(S(L_BH,M_BH)+6,3) + (b1x2*R(r_corona, M_BH)*R(r_corona, M_BH) + b1x1*R(r_corona, M_BH) + b1x0)*(S(L_BH, M_BH)+6) + (ax2*R(r_corona, M_BH)*R(r_corona, M_BH) + ax1*R(r_corona, M_BH) + ax0)
  return f2

def log10_E_peak(L_BH,M_BH,r_corona):
  # E_peak used to parametrize both the location in energy space and the shape of the Big Blue Bump of the disk emission.
  # E_peak in keV according to Thomas
  #rint('ours',f1(L_BH, M_BH, r_corona),f2(L_BH, M_BH, r_corona))
  log10_E_peak = max(f1(L_BH, M_BH, r_corona),f2(L_BH, M_BH, r_corona))
  return log10_E_peak


def alpha_ox(L_BH,M_BH):
  L_Edd     = 1.26*10**38*M_BH # in erg/s
  alpha_ox  =  -0.13*np.log(M_BH)+0.15*np.log10(L_BH/L_Edd)-0.45
  return alpha_ox

def F_nu(nu,L_BH,M_BH,r_corona):
  #This line is meant to convert from E_peak in kev to nu_peak in Hz
  #print(log10_E_peak(L_BH,M_BH,r_corona))
  numax_peak = 2.417e17*(10**log10_E_peak(L_BH,M_BH,r_corona))    # in Hz 

  nu1=4.8359e17 # in Hz?
  nu2=1.1992e15 # in Hz?

  param = (nu1**(alpha_UV) * np.exp(-nu1/numax_peak) * np.exp(-nu_IR/nu1)-
           10**(alpha_ox(L_BH,M_BH)*2.6056) * nu2**alpha_UV * np.exp(-nu2/numax_peak)*
           exp(-nu_IR/nu2))/(10**(alpha_ox(L_BH,M_BH)*2.6056) * nu2**
                             alpha_x - nu1**alpha_x)
  if param < 0:
    param = (10**(alpha_ox(L_BH,M_BH)*2.6056) * nu2**alpha_UV * exp(-nu2/numax_peak)*
             exp(-nu_IR /nu2))/(nu1**alpha_x)


  #PARAM = 0. ## set to 0 for now.
  PARAM = param
  #rint('numax_peak=',numax_peak)
  #print('factor Fnu,',np.exp(-nu / numax_peak), np.exp(-nu_IR / nu) )
  
  F_nu  = nu**alpha_UV * np.exp(-nu / numax_peak) * np.exp(-nu_IR / nu)  + PARAM*nu**alpha_x
  ##F_nu[np.where(nu<(0.1*3.2899e15))[0]] = nu[np.where(nu<(0.1*3.2899e15))[0]]**alpha_UV * np.exp(-nu[np.where(nu<(0.1*3.2899e15))[0]] / numax_peak) * np.exp(-nu_IR / nu[np.where(nu<(0.1*3.2899e15))[0]])
  for ii in range(len(nu)):
    if nu[ii]<3.2899e14: ### last term of Eq set to zero below 1.36 eV = 912 nm
      #print('nu= ',nu[ii],3.2899e14)
      F_nu[ii]  = nu[ii]**alpha_UV * np.exp(-nu[ii] / numax_peak) * np.exp(-nu_IR / nu[ii])
  return F_nu

def F_lambda(F_nu,nu):
  # from F_nu to F_lambda
  #from (erg/s/cm^2/Hz) to (erg/s/cm^2/A)
  F_lambda = F_nu*(3e18)/((3e18/nu)**2)
  return F_lambda


def make_spectrum_AGN(wavelength,bh_mass,bh_lum):
   
    L_BH  = 10**bh_lum # in erg/s
    M_BH  = bh_mass # in Msun
    L_Edd = 1.26*10**38*M_BH # in erg/s
    f_Edd_1 = np.log10(L_BH/L_Edd)
    
    nu = np.divide(3e18,wavelength) # from AA to Hz
    r_corona = 10.
    to_print_F_nu=F_nu(nu,L_BH,M_BH,r_corona)
    nu_peak = 10**(log10_E_peak(L_BH,M_BH,r_corona))*2.42e17
    ## normalization
    norm_1=(L_BH)/scipy.integrate.quadrature(F_nu,nu_peak*1e-3,nu_peak*1e3,args=(L_BH,M_BH,r_corona))[0]
    return(F_lambda(norm_1*to_print_F_nu, nu))

# %%
library = pd.read_csv('TNG_50_library/library_galaxies_with_BH.txt',header=None,
                    names=['galaxy number','age end SFR','Mstar end SFR','BH mass','BH Lum'])
cols = 2
rows = 6
j = 0
fig, axes = plt.subplots(rows, cols, figsize=(12, 16))
galaxy_num = library['galaxy number'].to_numpy()
for i in galaxy_num:
    if i == 1:
        for mm in [1e4,1e5,1e6,1e7,1e8,1e9]:

            age_gal = library['age end SFR'][library['galaxy number']==i]
            age_gal_i = int(age_gal.to_numpy()[0])

            df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_'+str(i)+'_age='+str(age_gal_i)+'.000.sed', header=None, skiprows=6)
            df = df[0].str.split(expand=True)
            #distance modulus at z = 8
            mu = 49.53
            wavelength = df[0].astype('float64').to_numpy()
            flux = df[1].astype('float64').to_numpy()
            #print(wavelength,flux)

            flux = 3.826e+33*flux
            #flux = 3.34e-19*flux*wavelength*wavelength
            #flux = flux*(3e+18/wavelength)
            #flux = (flux)/((4*np.pi*(10**2)))
            #flux = flux*(0.00000000000000000032408**2)
            bh_mass = library['BH mass'][library['galaxy number']==i].to_numpy()
            print(bh_mass)
            bh_lum = library['BH Lum'][library['galaxy number']==i].to_numpy()
            
            AGN = make_spectrum_AGN(wavelength, mm,bh_lum)
            axes[j][0].loglog(wavelength,flux,label='Galaxy '+str(i))
            axes[j][0].loglog(wavelength,AGN,label='AGN BH Mass '+str(mm))
            axes[j][1].loglog(wavelength,flux+AGN,label='Added Contributions '+str(i))
            axes[j][0].set_ylim(1e30,1e44)
            axes[j][0].legend()
            axes[j][1].set_ylim(1e30,1e44)
            axes[j][1].legend()
            j+=1

# %%
library = pd.read_csv('TNG_50_library/library_galaxies_with_BH.txt',header=None,
                    names=['galaxy number','age end SFR','Mstar end SFR','BH mass','BH Lum'])
cols = 2
rows = 6
j = 0
fig, axes = plt.subplots(rows, cols, figsize=(12, 16))
galaxy_num = library['galaxy number'].to_numpy()
for i in galaxy_num:
    if i == 1:
        for mm in [40,41,42,43,44,45]:

            age_gal = library['age end SFR'][library['galaxy number']==i]
            age_gal_i = int(age_gal.to_numpy()[0])

            df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_'+str(i)+'_age='+str(age_gal_i)+'.000.sed', header=None, skiprows=6)
            df = df[0].str.split(expand=True)
            #distance modulus at z = 8
            mu = 49.53
            wavelength = df[0].astype('float64').to_numpy()
            flux = df[1].astype('float64').to_numpy()
            #print(wavelength,flux)

            flux = 3.826e+33*flux
            #flux = 3.34e-19*flux*wavelength*wavelength
            #flux = flux*(3e+18/wavelength)
            #flux = (flux)/((4*np.pi*(10**2)))
            #flux = flux*(0.00000000000000000032408**2)
            bh_mass = library['BH mass'][library['galaxy number']==i].to_numpy()
            print(bh_mass)
            bh_lum = library['BH Lum'][library['galaxy number']==i].to_numpy()
            
            AGN = make_spectrum_AGN(wavelength, 1e8,mm)
            axes[j][0].loglog(wavelength,flux,label='Galaxy '+str(i))
            axes[j][0].loglog(wavelength,AGN,label='AGN BH Luminosity 10**'+str(mm))
            axes[j][1].loglog(wavelength,flux+AGN,label='Added Contributions '+str(i))
            axes[j][0].set_ylim(1e30,1e44)
            axes[j][0].legend()
            axes[j][1].set_ylim(1e30,1e44)
            axes[j][1].legend()
            j+=1
            
    return(F_lambda(norm_1*to_print_F_nu, nu))

# %%
library = pd.read_csv('TNG_50_library/library_galaxies_with_BH.txt',header=None,
                    names=['galaxy number','age end SFR','Mstar end SFR','BH mass','BH Lum'])
import matplotlib as mtp
mtp.rcParams['figure.figsize']=[20,10]
fig=plt.figure()
gs1=gridspec.GridSpec(1,2)
gs1.update(left=0.1,right=0.5, bottom=0.2, top=0.6, hspace=0.3, wspace=0.0)

z = 5
galaxy_num = library['galaxy number'].to_numpy()
i = 1

age_gal = library['age end SFR'][library['galaxy number']==i]
age_gal_i = int(age_gal.to_numpy()[0])
age_gal_i = round(age_gal_i*1e-9,3)

df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_'+str(i)+'_age=0'+str(age_gal_i)+'.sed', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)
flux = 3.826e+33*flux
AGN = make_spectrum_AGN(wavelength, 1e7,44)

ax=plt.subplot(gs1[0])
ax.tick_params(axis='both',which='both',direction='in',bottom=True,top=True,left=True,right=True)
ax.tick_params(right=False, labelright=False)

#ax.loglog(wavelength,flux,label='Galaxy '+str(i))
#ax.loglog(wavelength,AGN,label='AGN BH Luminosity 10**'+str(mm))
ax.loglog(wavelength*0.0001*(1+z),flux,label='Galaxy', linestyle='dotted', color='black')

ax.loglog(wavelength*0.0001*(1+z),AGN,label=r'$log_{10}(M_{BH}/M_{\odot})$=7', linestyle='dashed')
AGN = make_spectrum_AGN(wavelength, 1e8,44)
ax.loglog(wavelength*0.0001*(1+z),AGN,label=r'$log_{10}(M_{BH}/M_{\odot})$=8')
AGN = make_spectrum_AGN(wavelength, 1e6,44)
ax.loglog(wavelength*0.0001*(1+z),AGN,label=r'$log_{10}(M_{BH}/M_{\odot})$=6')
ax.set_ylim(1e33,1e44)
ax.set_xlim(3e-2,1e2)
ax.set_xlabel(r'$\lambda$ $[\mu m]$',fontsize=15)
ax.set_ylabel(r'$L_{\lambda}$ [erg/s/$\AA$]',fontsize=15)
ax.legend(frameon=False,fontsize=10,loc='upper right')
labels = ax.get_xticks()
ax.set_xticks(ticks = labels[2:-2])



AX2 = ax.twinx()
ff = ['F070','F090','F115','F150','F200','F277','F356','F444']
for f in ff:
    
    df = pd.read_csv('Filter/'+str(f)+'W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
    if f == 'F200':
        AX2.plot(df['Wavelength'].to_numpy()*0.0001, df['filter'].to_numpy()*0.5, label='F115W',color='red')
    else:
        AX2.plot(df['Wavelength'].to_numpy()*0.0001, df['filter'].to_numpy()*0.5, label='F115W',color='lightgray')
ff = ['F0560','F0770','F1000','F1130','F1280','F1500','F1800','F2100','F2550']
for f in ff:
    df = pd.read_csv('Filter/'+str(f)+'W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
    AX2.plot(df['Wavelength'].to_numpy()*0.0001, df['filter'].to_numpy(), label='F115W',color='dimgrey')
AX2.set_ylim([0,2])
AX2.tick_params(bottom=False, labelbottom=False, right=False, labelright=False)


ax=plt.subplot(gs1[1])
ax.tick_params(axis='both',which='both',direction='in',bottom=True,top=True,left=True,right=True)
ax.tick_params(left=False, labelleft=False)


AGN = make_spectrum_AGN(wavelength, 1e7,44)
#ax.loglog(wavelength,flux,label='Galaxy '+str(i))
#ax.loglog(wavelength,AGN,label='AGN BH Luminosity 10**'+str(mm)
ax.loglog(wavelength*0.0001*(1+z),flux,label='Galaxy', linestyle='dotted', color='black')

ax.loglog(wavelength*0.0001*(1+z),AGN,label=r'$log_{10}(L_{bol}$/(erg/s))=44', linestyle='dashed')
AGN = make_spectrum_AGN(wavelength, 1e7,43)
ax.loglog(wavelength*0.0001*(1+z),AGN,label=r'$log_{10}(L_{bol}$/(erg/s))=43')
AGN = make_spectrum_AGN(wavelength, 1e7,45)
ax.loglog(wavelength*0.0001*(1+z),AGN,label=r'$log_{10}(L_{bol}$/(erg/s))=45')
ax.set_ylim(1e33,1e44)
ax.set_xlim(3e-2,1e2)
ax.set_xlabel(r'$\lambda$ $[\mu m]$',fontsize=15)
#ax.set_ylabel(r'$L_{\lambda}$ in erg/s/$\AA$')
labels = ax.get_xticks()
ax.set_xticks(ticks = labels[2:-1])
ax.legend(frameon=False,fontsize=10,loc='upper right')

AX2 = ax.twinx()
ff = ['F070','F090','F115','F150','F200','F277','F356','F444']
for f in ff:
    
    df = pd.read_csv('Filter/'+str(f)+'W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
    if f == 'F200':
        AX2.plot(df['Wavelength'].to_numpy()*0.0001, df['filter'].to_numpy()*0.5, label='F115W',color='red')
    else:
        AX2.plot(df['Wavelength'].to_numpy()*0.0001, df['filter'].to_numpy()*0.5, label='F115W',color='lightgray')
ff = ['F0560','F0770','F1000','F1130','F1280','F1500','F1800','F2100','F2550']
for f in ff:
    df = pd.read_csv('Filter/'+str(f)+'W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
    AX2.plot(df['Wavelength'].to_numpy()*0.0001, df['filter'].to_numpy(), label='F115W',color='dimgrey')
AX2.set_ylim([0,2])
AX2.tick_params(bottom=False, labelbottom=False, right=False, labelright=False)
"""

for i in galaxy_num:
    if i == 1:
        ax=plt.subplot(gs1[0])
        ax.tick_params(axis='both',which='both',direction='in',bottom=True,top=True,left=True,right=True)
        for mm in [44,45,43]:
            print(mm)
            age_gal = library['age end SFR'][library['galaxy number']==i]
            age_gal_i = int(age_gal.to_numpy()[0])

            df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_'+str(i)+'_age='+str(age_gal_i)+'.000.sed', header=None, skiprows=6)
            df = df[0].str.split(expand=True)
            #distance modulus at z = 8
            mu = 49.53
            wavelength = df[0].astype('float64').to_numpy()
            flux = df[1].astype('float64').to_numpy()
            #print(wavelength,flux)

            flux = 3.826e+33*flux
            #flux = 3.34e-19*flux*wavelength*wavelength
            #flux = flux*(3e+18/wavelength)
            #flux = (flux)/((4*np.pi*(10**2)))
            #flux = flux*(0.00000000000000000032408**2)
            #bh_mass = library['BH mass'][library['galaxy number']==i].to_numpy()
            #print(bh_mass)
            #bh_lum = library['BH Lum'][library['galaxy number']==i].to_numpy()
            
            AGN = make_spectrum_AGN(wavelength, 1e7,mm)
            #ax.loglog(wavelength,flux,label='Galaxy '+str(i))
            #ax.loglog(wavelength,AGN,label='AGN BH Luminosity 10**'+str(mm))
            ax.loglog(wavelength,flux+AGN,label='Added Contributions '+str(i))
            ax.set_ylim(1e30,1e44)
            ax.legend()
            ax.set_ylim(1e30,1e44)
            ax.legend()
            print('xxxxx')
        print('hello')
        ax=plt.subplot(gs1[1])
        ax.tick_params(axis='both',which='both',direction='in',bottom=True,top=True,left=True,right=True)
        for mm in [7,6,8]:
            print('ffffff')
            age_gal = library['age end SFR'][library['galaxy number']==i]
            age_gal_i = int(age_gal.to_numpy()[0])

            #df = pd.read_csv('TNG_50_library\TNG50_out_17_gal_'+str(i)+'_age='+str(age_gal_i)+'.000.sed', header=None, skiprows=6)
            #df = df[0].str.split(expand=True)
            #distance modulus at z = 8
            #mu = 49.53
            wavelength = df[0].astype('float64').to_numpy()
            #flux = df[1].astype('float64').to_numpy()
            #print(wavelength,flux)

            #flux = 3.826e+33*flux
            #flux = 3.34e-19*flux*wavelength*wavelength
            #flux = flux*(3e+18/wavelength)
            #flux = (flux)/((4*np.pi*(10**2)))
            #flux = flux*(0.00000000000000000032408**2)
            #bh_mass = library['BH mass'][library['galaxy number']==i].to_numpy()
            #print(bh_mass)
            #bh_lum = library['BH Lum'][library['galaxy number']==i].to_numpy()
            print(mm)
            AGN = make_spectrum_AGN(wavelength, 10**mm, 10**44)
            ax.loglog(wavelength,flux,label='Galaxy '+str(i))
            ax.loglog(wavelength,AGN,label='AGN BH Mass 10**'+str(mm))
            ax.loglog(wavelength,flux+AGN,label='Added Contributions '+str(i))
            ax.set_ylim(1e30,1e44)
            ax.legend()
            ax.set_ylim(1e30,1e44)
            ax.legend()
"""
# Out:
# "\n\nfor i in galaxy_num:\n    if i == 1:\n        ax=plt.subplot(gs1[0])\n        ax.tick_params(axis='both',which='both',direction='in',bottom=True,top=True,left=True,right=True)\n        for mm in [44,45,43]:\n            print(mm)\n            age_gal = library['age end SFR'][library['galaxy number']==i]\n            age_gal_i = int(age_gal.to_numpy()[0])\n\n            df = pd.read_csv('TNG_50_library\\TNG50_out_17_gal_'+str(i)+'_age='+str(age_gal_i)+'.000.sed', header=None, skiprows=6)\n            df = df[0].str.split(expand=True)\n            #distance modulus at z = 8\n            mu = 49.53\n            wavelength = df[0].astype('float64').to_numpy()\n            flux = df[1].astype('float64').to_numpy()\n            #print(wavelength,flux)\n\n            flux = 3.826e+33*flux\n            #flux = 3.34e-19*flux*wavelength*wavelength\n            #flux = flux*(3e+18/wavelength)\n            #flux = (flux)/((4*np.pi*(10**2)))\n            #flux = flux*(0.000000000000000000324
# ...

# %%
library = pd.read_csv('TNG_50_library/library_galaxies_with_BH.txt',header=None,
                    names=['galaxy number','age end SFR','Mstar end SFR','BH mass','BH Lum'])
import matplotlib as mtp
mtp.rcParams['figure.figsize']=[30,10]
fig=plt.figure()
gs1=gridspec.GridSpec(1,4)
gs1.update(left=0.1,right=0.5, bottom=0.2, top=0.6, hspace=0.3, wspace=0.6)

z =5 
galaxy_num = library['galaxy number'].to_numpy()
i = 0

age_gal = library['age end SFR'][library['galaxy number']==i]
age_gal_i = int(age_gal.to_numpy()[0])
age_gal_i = round(age_gal_i*1e-9,3)

df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_'+str(i)+'_age=0'+str(age_gal_i)+'.sed', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)
flux = 3.826e+33*flux

ax=plt.subplot(gs1[0])
ax.tick_params(axis='both',which='both',direction='in',bottom=True,top=True,left=True,right=True)

#ax.loglog(wavelength,flux,label='Galaxy '+str(i))
#ax.loglog(wavelength,AGN,label='AGN BH Luminosity 10**'+str(mm))
ax.loglog(wavelength*(1+z),flux,label='Galaxy 0', linestyle='dotted', color='black')
df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_'+str(i)+'_mod.152', header=None,skiprows=6)
df = df[0].str.split(expand=True)

#print(df)
#ax.loglog(wavelength,df[1],label='Galaxy at z =5', linestyle='dotted', color='green')

df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_'+str(i)+'_mod_age=0'+str(age_gal_i)+'_mod.sed', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)
flux = 3.826e+33*flux
ax.loglog(wavelength*(1+z),flux,label='Galaxy 0 with AGN', linestyle='dotted', color='red')



ax2 = ax.twinx()

df = pd.read_csv('Filter/F115W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F115W')

df = pd.read_csv('Filter/F150W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F150W')

df = pd.read_csv('Filter/F200W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F200W')

df = pd.read_csv('Filter/F277W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F277W')

df = pd.read_csv('Filter/F356W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F356W')

df = pd.read_csv('Filter/F444W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F444W')
df = pd.read_csv('Filter/F0770W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F700W')

print()
df = pd.read_csv('Filter/F1000W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1000W')

df = pd.read_csv('Filter/F1280W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1280W')

df = pd.read_csv('Filter/F1500W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1500W')

df = pd.read_csv('Filter/F1800W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1800W')

df = pd.read_csv('Filter/F2100W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F2100W')
ax2.set_ylim(0,2)
ax2.set_ylabel('Filter sensitivity for JWST')




ax.set_ylim(1e35,1e44)
#ax.set_ylim(1e2,1e5)
ax.set_ylabel('Luminosity in erg/s/A')
ax.set_xlabel('Wavelength in A')
ax.legend()


i = 1

age_gal = library['age end SFR'][library['galaxy number']==i]
age_gal_i = int(age_gal.to_numpy()[0])
age_gal_i = round(age_gal_i*1e-9,3)

df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_'+str(i)+'_age=0'+str(age_gal_i)+'.sed', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)
flux = 3.826e+33*flux


ax=plt.subplot(gs1[1])
ax.tick_params(axis='both',which='both',direction='in',bottom=True,top=True,left=True,right=True)

#ax.loglog(wavelength,flux,label='Galaxy '+str(i))
#ax.loglog(wavelength,AGN,label='AGN BH Luminosity 10**'+str(mm))
ax.loglog(wavelength*(1+z),flux,label='Galaxy 1', linestyle='dotted', color='black')



ax2 = ax.twinx()
df = pd.read_csv('Filter/F115W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F115W')

df = pd.read_csv('Filter/F150W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F150W')

df = pd.read_csv('Filter/F200W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F200W')

df = pd.read_csv('Filter/F277W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F277W')

df = pd.read_csv('Filter/F356W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F356W')

df = pd.read_csv('Filter/F444W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F444W')

df = pd.read_csv('Filter/F0770W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F700W')

df = pd.read_csv('Filter/F1000W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1000W')

df = pd.read_csv('Filter/F1280W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1280W')

df = pd.read_csv('Filter/F1500W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1500W')

df = pd.read_csv('Filter/F1800W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1800W')

df = pd.read_csv('Filter/F2100W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F2100W')
ax2.set_ylim(0,2)
ax2.set_ylabel('Filter sensitivity for JWST')




df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_'+str(i)+'_mod_age=0'+str(age_gal_i)+'_mod.sed', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)
flux = 3.826e+33*flux
ax.loglog(wavelength*(1+z),flux,label='Galaxy 1 with AGN', linestyle='dotted', color='red')



ax.set_ylim(1e35,1e44)
ax.set_ylabel('Luminosity in erg/s/A')
ax.set_xlabel('Wavelength in A')
ax.legend()



i = 2

age_gal = library['age end SFR'][library['galaxy number']==i]
age_gal_i = int(age_gal.to_numpy()[0])
age_gal_i = round(age_gal_i*1e-9,3)

df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_'+str(i)+'_age=0'+str(age_gal_i)+'.sed', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)
flux = 3.826e+33*flux


ax=plt.subplot(gs1[2])
ax.tick_params(axis='both',which='both',direction='in',bottom=True,top=True,left=True,right=True)

#ax.loglog(wavelength,flux,label='Galaxy '+str(i))
#ax.loglog(wavelength,AGN,label='AGN BH Luminosity 10**'+str(mm))
ax.loglog(wavelength*(1+z),flux,label='Galaxy 1', linestyle='dotted', color='black')



ax2 = ax.twinx()
df = pd.read_csv('Filter/F115W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F115W')

df = pd.read_csv('Filter/F150W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F150W')

df = pd.read_csv('Filter/F200W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F200W')

df = pd.read_csv('Filter/F277W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F277W')

df = pd.read_csv('Filter/F356W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F356W')

df = pd.read_csv('Filter/F444W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F444W')

df = pd.read_csv('Filter/F0770W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F700W')

df = pd.read_csv('Filter/F1000W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1000W')

df = pd.read_csv('Filter/F1280W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1280W')

df = pd.read_csv('Filter/F1500W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1500W')

df = pd.read_csv('Filter/F1800W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1800W')

df = pd.read_csv('Filter/F2100W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F2100W')
ax2.set_ylim(0,2)
ax2.set_ylabel('Filter sensitivity for JWST')




df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_'+str(i)+'_mod_age=0'+str(age_gal_i)+'_mod.sed', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)
flux = 3.826e+33*flux
ax.loglog(wavelength*(1+z),flux,label='Galaxy 1 with AGN', linestyle='dotted', color='red')



ax.set_ylim(1e35,1e44)
ax.set_ylabel('Luminosity in erg/s/A')
ax.set_xlabel('Wavelength in A')
ax.legend()


i = 3

age_gal = library['age end SFR'][library['galaxy number']==i]
age_gal_i = int(age_gal.to_numpy()[0])
age_gal_i = round(age_gal_i*1e-9,3)

df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_'+str(i)+'_age=0'+str(age_gal_i)+'.sed', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)
flux = 3.826e+33*flux


ax=plt.subplot(gs1[3])
ax.tick_params(axis='both',which='both',direction='in',bottom=True,top=True,left=True,right=True)

#ax.loglog(wavelength,flux,label='Galaxy '+str(i))
#ax.loglog(wavelength,AGN,label='AGN BH Luminosity 10**'+str(mm))
ax.loglog(wavelength*(1+z),flux,label='Galaxy 1', linestyle='dotted', color='black')



ax2 = ax.twinx()
df = pd.read_csv('Filter/F115W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F115W')

df = pd.read_csv('Filter/F150W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F150W')

df = pd.read_csv('Filter/F200W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F200W')

df = pd.read_csv('Filter/F277W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F277W')

df = pd.read_csv('Filter/F356W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F356W')

df = pd.read_csv('Filter/F444W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F444W')

df = pd.read_csv('Filter/F0770W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F700W')

df = pd.read_csv('Filter/F1000W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1000W')

df = pd.read_csv('Filter/F1280W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1280W')

df = pd.read_csv('Filter/F1500W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1500W')

df = pd.read_csv('Filter/F1800W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1800W')

df = pd.read_csv('Filter/F2100W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
ax2.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F2100W')
ax2.set_ylim(0,2)
ax2.set_ylabel('Filter sensitivity for JWST')




df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_'+str(i)+'_mod_age=0'+str(age_gal_i)+'_mod.sed', header=None, skiprows=6)
df = df[0].str.split(expand=True)
#distance modulus at z = 8
mu = 49.53
wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
#print(wavelength,flux)
flux = 3.826e+33*flux
ax.loglog(wavelength*(1+z),flux,label='Galaxy 1 with AGN', linestyle='dotted', color='red')



ax.set_ylim(1e35,1e44)
ax.set_ylabel('Luminosity in erg/s/A')
ax.set_xlabel('Wavelength in A')
ax.legend()
fig.tight_layout()

# %%
df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_2_mod.153','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)

wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
plt.plot(wavelength,flux*3.826e+33, label='1 Gyr with AGN')

#df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_1_elines.162','/s', header=None, skiprows=6)
#df = df[0].str.split(expand=True)

#wavelength = df[0].astype('float64').to_numpy()
#flux = df[1].astype('float64').to_numpy()
#plt.plot(wavelength,flux, label='1 Gyr Galaxy 0')


df = pd.read_csv('TNG_50_library/TNG50_out_17_gal_2_elines.153','/s', header=None, skiprows=6)
df = df[0].str.split(expand=True)

wavelength = df[0].astype('float64').to_numpy()
flux = df[1].astype('float64').to_numpy()
plt.plot(wavelength,flux*3.826e+33, label='1 Gyr Galaxy 2')


plt.xscale('log')
plt.yscale('log')
plt.ylabel(r'$\rm L_{\lambda} [erg/s/\AA]$')
plt.xlabel(r'$\rm \lambda [\AA]$')
plt.ylim(1e37,1e41)
plt.xlim(1e2,1e6)
plt.legend()
plt.savefig('Figures/galaxy_with_emissionLines.png')
plt.show()
# Out:
# C:\Users\clara\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py:3553: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
# c:\Users\clara\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
