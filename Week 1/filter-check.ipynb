# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import csv
import pandas as pd
import os

# %%
df = pd.read_csv('F115W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F115W')

df = pd.read_csv('F150W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F150W')

df = pd.read_csv('F200W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F200W')

df = pd.read_csv('F277W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F277W')

df = pd.read_csv('F356W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F356W')

df = pd.read_csv('F444W_JWST_NIRCAM.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F444W')

df = pd.read_csv('F1000W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F1000W')

df = pd.read_csv('F2100W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy(), df['filter'].to_numpy(), label='F2100W')

plt.legend()
plt.xlabel(r'Wavelength in Â')
plt.savefig('Figures/filter_JWST')
plt.show()

# %%
df = pd.read_csv('F0770W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy()*0.0001, df['filter'].to_numpy(), label='F700W')

df = pd.read_csv('F1000W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy()*0.0001, df['filter'].to_numpy(), label='F1000W')

df = pd.read_csv('F1280W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy()*0.0001, df['filter'].to_numpy(), label='F1280W')

df = pd.read_csv('F1500W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy()*0.0001, df['filter'].to_numpy(), label='F1500W')

df = pd.read_csv('F1800W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy()*0.0001, df['filter'].to_numpy(), label='F1800W')

df = pd.read_csv('F2100W_JWST_MIRI.txt', delimiter= '\s+', skiprows=(1),names=['Wavelength','filter'])
plt.plot(df['Wavelength'].to_numpy()*0.0001, df['filter'].to_numpy(), label='F2100W')


plt.legend(fontsize="x-small")
plt.xlim([5,25])
plt.xlabel(r'Wavelength in $\mu$m')
plt.savefig('Figures/filter_JWST2')
plt.show()

# %%
df = pd.read_csv('SFR-trials/sfr0.txt', delimiter= '\s+', skiprows=30,)
print(df)
#plt.plot(df['Wavelength'].to_numpy()*0.0001, df['filter'].to_numpy(), label='F1500W')
# Out:
#       0.000000  -4.8342  -0.2082   0.1044  1.0506  1.0000E+00  0.0000E+00  \
# 0     5.000000  -4.8342  -0.2082   0.1044  1.0506    1.000000     0.00000
# 1     5.149989  -4.8365  -0.2116   0.1010  1.0467    0.999970     0.00000
# 2     5.200002  -4.8384  -0.2142   0.0983  1.0437    0.999970     0.00000
# 3     5.250005  -4.8403  -0.2167   0.0957  1.0408    0.999970     0.00000
# 4     5.300008  -4.8423  -0.2191   0.0932  1.0380    0.999970     0.00000
# ..         ...      ...      ...      ...     ...         ...         ...
# 215  10.278753  10.2529  11.2337  10.6357  8.6209    0.014289     0.16153
# 216  10.284431  10.2685  11.2522  10.6527  8.6353    0.014243     0.16155
# 217  10.290034  10.2841  11.2705  10.6695  8.6497    0.014197     0.16157
# 218  10.295568  10.2995  11.2887  10.6862  8.6641    0.014152     0.16159
# 219  10.301030  10.3149  11.3068  10.7028  8.6784    0.014107     0.16161
#
#      0.0000E+00.1  1.0000E+00.1  0.0000E+00.2  1.0000E+00.2  5.4540E-03  \
# ...
